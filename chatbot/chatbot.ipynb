# %%
# !pip install -q streamlit
# !npm install -g localtunnel
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 133.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 121.5 MB/s eta 0:00:00
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹
# added 22 packages in 2s
# ⠹
# ⠹3 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹npm notice
# npm notice New major version of npm available! 10.8.2 -> 12.0.0
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v12.0.0
# npm notice To update run: npm install -g npm@12.0.0
# npm notice
# ⠹

# %%
# !streamlit run Chatbot/chatbot_app.py & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼⠴2026-07-09 16:17:07.274 Uvicorn server started on :::8501
# your url is: https://true-cows-scream.loca.lt
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.142.233.128:8501
#
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#   Stopping...
# ^C

# %%
# !pip install pyngrok
# !ngrok config add-authtoken 3GH2BhYoLbZ0Z2ekidSSbXJ2pNh_jHVTvNXgggAsPNQLxc21
# Out:
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
import os

# Masuk ke folder Chatbot tempat data.pth berada
os.chdir('/content/Chatbot')

# Jalankan streamlit di latar belakang
os.system("streamlit run chatbot_app.py &")

# Buka terowongan ngrok ke port Streamlit
public_url = ngrok.connect(8501)
print("Klik tautan resmi ini untuk membuka Chatbot Anda:", public_url)
# Out:
# Klik tautan resmi ini untuk membuka Chatbot Anda: NgrokTunnel: "https://proposal-preflight-operate.ngrok-free.dev" -> "http://localhost:8501"

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True
